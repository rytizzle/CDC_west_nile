# %%
import pandas as pd

# %%
#import the data to look at
df_train = pd.read_csv('./assets/input/train.csv')
df_train = df_train.drop(df_train[df_train.AddressAccuracy == 3].index) #drop low GPS tracking Accuracy
df_train.head(1)
# Out:
#          Date                                            Address  \
# 0  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
#
#               AddressNumberAndStreet  Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
#
#    NumMosquitos  WnvPresent
# 0             1           0

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10415 entries, 0 to 10505
# Data columns (total 12 columns):
# Date                      10415 non-null object
# Address                   10415 non-null object
# Species                   10415 non-null object
# Block                     10415 non-null int64
# Street                    10415 non-null object
# Trap                      10415 non-null object
# AddressNumberAndStreet    10415 non-null object
# Latitude                  10415 non-null float64
# Longitude                 10415 non-null float64
# AddressAccuracy           10415 non-null int64
# NumMosquitos              10415 non-null int64
# WnvPresent                10415 non-null int64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 1.0+ MB

# %%
df_train.describe()
# Out:
#               Block      Latitude     Longitude  AddressAccuracy  \
# count  10415.000000  10415.000000  10415.000000     10415.000000
# mean      35.623908     41.840816    -87.700521         7.861642
# std       24.435937      0.113180      0.096711         1.387329
# min       10.000000     41.644612    -87.930995         5.000000
# 25%       12.000000     41.732984    -87.760886         8.000000
# 50%       33.000000     41.846075    -87.696269         8.000000
# 75%       52.000000     41.954690    -87.627796         9.000000
# max       98.000000     42.017430    -87.531635         9.000000
#
#        NumMosquitos    WnvPresent
# count   10415.00000  10415.000000
# mean       12.92722      0.052808
# std        16.17412      0.223662
# min         1.00000      0.000000
# 25%         2.00000      0.000000
# 50%         5.00000      0.000000
# 75%        17.00000      0.000000
# max        50.00000      1.000000

# %%
df_train['Species'].value_counts()
# Out:
# CULEX PIPIENS/RESTUANS    4710
# CULEX RESTUANS            2713
# CULEX PIPIENS             2681
# CULEX TERRITANS            220
# CULEX SALINARIUS            84
# CULEX TARSALIS               6
# CULEX ERRATICUS              1
# Name: Species, dtype: int64

# %%
df_train['WnvPresent'].value_counts(normalize = True)
# Out:
# 0    0.947192
# 1    0.052808
# Name: WnvPresent, dtype: float64

# %%
df_train[df_train['WnvPresent'] == 1].shape
# Out:
# (550, 12)

# %%
df_train.groupby('NumMosquitos')

# %%
df_train[df_train['NumMosquitos'] == 50]
# Out:
#              Date                                            Address  \
# 293    2007-07-11     2200 West 113th Street, Chicago, IL 60643, USA
# 295    2007-07-11     2200 West 113th Street, Chicago, IL 60643, USA
# 350    2007-07-11     3500 West 116th Street, Chicago, IL 60655, USA
# 351    2007-07-11     3500 West 116th Street, Chicago, IL 60655, USA
# 353    2007-07-11     3500 West 116th Street, Chicago, IL 60655, USA
# 529    2007-07-18                South Doty Avenue, Chicago, IL, USA
# 530    2007-07-18        South Stony Island Avenue, Chicago, IL, USA
# 531    2007-07-18        South Stony Island Avenue, Chicago, IL, USA
# 533    2007-07-18        South Stony Island Avenue, Chicago, IL, USA
# 547    2007-07-18          3700 118th Street, Chicago, IL 60617, USA
# 548    2007-07-18          3700 118th Street, Chicago, IL 60617, USA
# 553    2007-07-18     3800 East 115th Street, Chicago, IL 60617, USA
# 572    2007-07-19        South Stony Island Avenue, Chicago, IL, USA
# ...

# %%
df_train[df_train['AddressAccuracy'] == 4]
# Out:
# Empty DataFrame
# Columns: [Date, Address, Species, Block, Street, Trap, AddressNumberAndStreet, Latitude, Longitude, AddressAccuracy, NumMosquitos, WnvPresent]
# Index: []

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.regplot(x = 'WnvPresent', y = 'NumMosquitos', data = df_train)

# %%
df_train.groupby('Species')['WnvPresent'].value_counts().plot(kind = 'bar')

# %%
df_train['Date'] = pd.to_datetime(df_train['Date'])

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10415 entries, 0 to 10505
# Data columns (total 12 columns):
# Date                      10415 non-null datetime64[ns]
# Address                   10415 non-null object
# Species                   10415 non-null object
# Block                     10415 non-null int64
# Street                    10415 non-null object
# Trap                      10415 non-null object
# AddressNumberAndStreet    10415 non-null object
# Latitude                  10415 non-null float64
# Longitude                 10415 non-null float64
# AddressAccuracy           10415 non-null int64
# NumMosquitos              10415 non-null int64
# WnvPresent                10415 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(5)
# memory usage: 1.0+ MB

# %%
df_train['Date'].dt.year
# Out:
# 0        2007
# 1        2007
# 2        2007
# 3        2007
# 4        2007
# 5        2007
# 6        2007
# 7        2007
# 8        2007
# 9        2007
# 10       2007
# 11       2007
# 12       2007
# 13       2007
# 14       2007
# 15       2007
# 16       2007
# 17       2007
# 18       2007
# 19       2007
# 20       2007
# 21       2007
# 22       2007
# 23       2007
# 24       2007
# 25       2007
# 26       2007
# 27       2007
# 28       2007
# 29       2007
#          ...
# 10476    2013
# 10477    2013
# 10478    2013
# 10479    2013
# 10480    2013
# 10481    2013
# 10482    2013
# 10483    2013
# 10484    2013
# 10485    2013
# 10486    2013
# 10487    2013
# 10488    2013
# 10489    2013
# 10490    2013
# 10491    2013
# 10492    2013
# 10493    2013
# 10494    2013
# 10495    2013
# 10496    2013
# 10497    2013
# 10498    2013
# 10499    2013
# 10500    2013
# 10501    2013
# 10502    2013
# 10503    2013
# 10504    2013
# 10505    2013
# ...

# %%
df_train['Date'].value_counts()
# Out:
# 2007-08-01    541
# 2007-08-15    274
# 2013-08-01    184
# 2007-10-04    184
# 2007-08-24    182
# 2013-07-12    182
# 2007-08-21    182
# 2007-08-07    180
# 2013-08-08    180
# 2013-07-19    180
# 2011-07-25    177
# 2011-07-15    176
# 2013-08-22    166
# 2007-09-24    165
# 2009-07-17    163
# 2013-08-15    155
# 2013-07-25    152
# 2007-07-11    150
# 2011-07-11    144
# 2013-08-29    142
# 2013-09-06    141
# 2007-08-22    139
# 2009-07-31    139
# 2011-08-05    138
# 2013-09-12    138
# 2011-07-29    137
# 2007-08-02    137
# 2011-09-12    136
# 2007-09-12    135
# 2009-08-07    131
#              ...
# 2007-07-27     81
# 2009-06-05     77
# 2013-06-07     76
# 2007-07-02     73
# 2009-07-13     71
# 2007-06-26     69
# 2009-10-01     65
# 2011-06-10     62
# 2013-06-27     62
# 2013-06-28     60
# 2011-09-30     60
# 2011-09-01     60
# 2009-05-28     59
# 2007-06-05     59
# 2007-08-17     54
# 2009-08-27     54
# 2009-09-03     53
# 2009-06-22     52
# 2007-09-06     50
# ...

# %%
df_train['AddressAccuracy'].value_counts()
# Out:
# 8    4628
# 9    3980
# 5    1807
# Name: AddressAccuracy, dtype: int64

# %%
df_train[df_train['AddressAccuracy']==3]

#df = df.drop(df[df.score < 50].index)
# Out:
# Empty DataFrame
# Columns: [Date, Address, Species, Block, Street, Trap, AddressNumberAndStreet, Latitude, Longitude, AddressAccuracy, NumMosquitos, WnvPresent]
# Index: []

# %%
df_train.groupby('Trap')['WnvPresent'].mean().plot(kind = 'bar')

# %% [markdown]
# # Create DataFrame combining more than 50 mosquitos caught

# %%
df_test = df_train[df_train['NumMosquitos']== 50]
df_no_50 = df_train[df_train['NumMosquitos'] != 50]
sum_50s = df_test.groupby(['Date', 'Address', 'Species', 'Block', 'Street', 'Trap', 'AddressNumberAndStreet', 'Latitude',
                 'Longitude', 'AddressAccuracy', 'WnvPresent'])['NumMosquitos'].transform('sum')
df_test['NumMosquitos'] = sum_50s
to_append = df_test.drop_duplicates()
df = to_append
df.shape
# Out:
# /Users/rytizzle/anaconda3/envs/dsi/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (312, 12)

# %%
sum_50s = df_test.groupby(['Date', 'Address', 'Species', 'Block', 'Street', 'Trap', 'AddressNumberAndStreet', 'Latitude',
                 'Longitude', 'AddressAccuracy', 'WnvPresent'])['NumMosquitos'].transform('sum')
sum_50s[:3]
# Out:
# 293    200
# 295    200
# 350    450
# Name: NumMosquitos, dtype: int64

# %%
df_test['NumMosquitos'] = sum_50s
df_test
# Out:
# /Users/rytizzle/anaconda3/envs/dsi/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#             Date                                            Address  \
# 293   2007-07-11     2200 West 113th Street, Chicago, IL 60643, USA
# 295   2007-07-11     2200 West 113th Street, Chicago, IL 60643, USA
# 350   2007-07-11     3500 West 116th Street, Chicago, IL 60655, USA
# 351   2007-07-11     3500 West 116th Street, Chicago, IL 60655, USA
# 353   2007-07-11     3500 West 116th Street, Chicago, IL 60655, USA
# 529   2007-07-18                South Doty Avenue, Chicago, IL, USA
# 530   2007-07-18        South Stony Island Avenue, Chicago, IL, USA
# ...

# %%
to_append = df_test.drop_duplicates()
df = to_append

# %%
df = to_append.append(df_no_50)

# %%
df = to_append

# %%
df[df['NumMosquitos'] > 50]
# Out:
#             Date                                            Address  \
# 293   2007-07-11     2200 West 113th Street, Chicago, IL 60643, USA
# 350   2007-07-11     3500 West 116th Street, Chicago, IL 60655, USA
# 530   2007-07-18        South Stony Island Avenue, Chicago, IL, USA
# 547   2007-07-18          3700 118th Street, Chicago, IL 60617, USA
# 586   2007-07-19          3700 118th Street, Chicago, IL 60617, USA
# 601   2007-07-25                South Doty Avenue, Chicago, IL, USA
# 603   2007-07-25                South Doty Avenue, Chicago, IL, USA
# 614   2007-07-25                South Doty Avenue, Chicago, IL, USA
# 618   2007-07-25                South Doty Avenue, Chicago, IL, USA
# 666   2007-07-25        South Stony Island Avenue, Chicago, IL, USA
# 674   2007-07-25        South Stony Island Avenue, Chicago, IL, USA
# 813   2007-08-01     2200 West 113th Street, Chicago, IL 60643, USA
# 1196  2007-08-01                South Doty Avenue, Chicago, IL, USA
# ...

# %%
df.iloc[0]
# Out:
# Date                                                 2007-07-11 00:00:00
# Address                   2200 West 113th Street, Chicago, IL 60643, USA
# Species                                           CULEX PIPIENS/RESTUANS
# Block                                                                 22
# Street                                                        W 113TH ST
# Trap                                                                T086
# AddressNumberAndStreet                     2200  W 113TH ST, Chicago, IL
# Latitude                                                         41.6883
# Longitude                                                       -87.6767
# AddressAccuracy                                                        8
# NumMosquitos                                                         200
# WnvPresent                                                             0
# Name: 293, dtype: object

# %%
df.sort_index(inplace = True)
df.iloc[280:]
# Out:
#             Date                                            Address  \
# 9414  2013-08-08     3500 West 116th Street, Chicago, IL 60655, USA
# 9437  2013-08-08  1000 North Central Park Avenue, Chicago, IL 60...
# 9453  2013-08-08   6700 South Kedzie Avenue, Chicago, IL 60629, USA
# 9483  2013-08-08                South Doty Avenue, Chicago, IL, USA
# 9503  2013-08-08     4000 East 130th Street, Chicago, IL 60633, USA
# 9508  2013-08-08    9100 West Higgins Road, Rosemont, IL 60018, USA
# 9524  2013-08-08  8200 South Kostner Avenue, Chicago, IL 60652, USA
# 9544  2013-08-08   7100 North Harlem Avenue, Chicago, IL 60631, USA
# 9546  2013-08-08   7100 North Harlem Avenue, Chicago, IL 60631, USA
# 9572  2013-08-15  5800 North Western Avenue, Chicago, IL 60659, USA
# 9617  2013-08-15  1000 North Central Park Avenue, Chicago, IL 60...
# 9829  2013-08-22    9100 West Higgins Road, Rosemont, IL 60018, USA
# 9901  2013-08-29  University of Illinois at Chicago, 1100 South ...
# ...

# %%
df_train[df_train['NumMosquitos'] == 50]
# Out:
#             Date                                            Address  \
# 293   2007-07-11     2200 West 113th Street, Chicago, IL 60643, USA
# 295   2007-07-11     2200 West 113th Street, Chicago, IL 60643, USA
# 350   2007-07-11     3500 West 116th Street, Chicago, IL 60655, USA
# 351   2007-07-11     3500 West 116th Street, Chicago, IL 60655, USA
# 353   2007-07-11     3500 West 116th Street, Chicago, IL 60655, USA
# 529   2007-07-18                South Doty Avenue, Chicago, IL, USA
# 530   2007-07-18        South Stony Island Avenue, Chicago, IL, USA
# 531   2007-07-18        South Stony Island Avenue, Chicago, IL, USA
# 533   2007-07-18        South Stony Island Avenue, Chicago, IL, USA
# 547   2007-07-18          3700 118th Street, Chicago, IL 60617, USA
# 548   2007-07-18          3700 118th Street, Chicago, IL 60617, USA
# 553   2007-07-18     3800 East 115th Street, Chicago, IL 60617, USA
# 572   2007-07-19        South Stony Island Avenue, Chicago, IL, USA
# ...

# %%
df_train.iloc[290:296]
# Out:
#           Date                                         Address  \
# 294 2007-07-11  2200 West 113th Street, Chicago, IL 60643, USA
# 295 2007-07-11  2200 West 113th Street, Chicago, IL 60643, USA
# 296 2007-07-11  2200 West 113th Street, Chicago, IL 60643, USA
# 297 2007-07-11  2200 West 113th Street, Chicago, IL 60643, USA
# 298 2007-07-11  2200 West 113th Street, Chicago, IL 60643, USA
# 299 2007-07-11  2200 West 113th Street, Chicago, IL 60643, USA
#
#                     Species  Block       Street  Trap  \
# 294  CULEX PIPIENS/RESTUANS     22   W 113TH ST  T086
# 295  CULEX PIPIENS/RESTUANS     22   W 113TH ST  T086
# 296  CULEX PIPIENS/RESTUANS     22   W 113TH ST  T086
# 297          CULEX RESTUANS     22   W 113TH ST  T086
# 298          CULEX RESTUANS     22   W 113TH ST  T086
# 299           CULEX PIPIENS     22   W 113TH ST  T086
#
#             AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# ...

# %%
df_train.groupby('Species')['NumMosquitos'].sum()
# Out:
# Species
# CULEX ERRATICUS               7
# CULEX PIPIENS             44543
# CULEX PIPIENS/RESTUANS    66043
# CULEX RESTUANS            23386
# CULEX SALINARIUS            143
# CULEX TARSALIS                7
# CULEX TERRITANS             508
# Name: NumMosquitos, dtype: int64

# %%
#mosquitos by lat/long by year
# to_csv = df_train.groupby(['year', 'Latitude', 'Longitude'])['NumMosquitos'].sum()

# %%
df_train
# Out:
#             Date                                            Address  \
# 0     2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1     2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2     2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3     2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4     2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 5     2007-05-29   1500 West Webster Avenue, Chicago, IL 60614, USA
# 6     2007-05-29     2500 West Grand Avenue, Chicago, IL 60654, USA
# 7     2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA
# 8     2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA
# 9     2007-05-29   1100 West Chicago Avenue, Chicago, IL 60642, USA
# 10    2007-05-29    2100 North Stave Street, Chicago, IL 60647, USA
# 11    2007-05-29    2200 North Cannon Drive, Chicago, IL 60614, USA
# 12    2007-05-29    2200 North Cannon Drive, Chicago, IL 60614, USA
# ...

# %%
# to_excel_wnb = df_train.groupby(['year', 'Latitude', 'Longitude'])['WnvPresent'].sum()

# %%
# to_excel_wnb.to_csv('wnv_latlong_year.csv')

# %%
df_train.groupby(['Date', 'Latitude', 'Longitude'])[]
# Out:
#   File "<ipython-input-39-f3f77f812f17>", line 1
#     df_train.groupby(['Date', 'Latitude', 'Longitude'])[]
#                                                         ^
# SyntaxError: invalid syntax

# %%
df_train.groupby(['Date', 'Latitude', 'Longitude'])['WnvPresent'].sum()

# %%
df_train

# %% [markdown]
# # Take a look at the test data

# %%
df_test = pd.read_csv('./assets/input/test.csv')

# %%
df_test

# %%
X['Date'] = pd.to_datetime(df_train['Date'])
X = df_test.loc[:,['Date', 'Species', 'Latitude', 'Longitude']]
pd.get_dummies(X)

# %%
df_test

# %%
import matplotlib

# %%
matplotlib.__version__

# %% [markdown]
# # Convert to Zones lat/long

# %%
df_train
# Out:
#             Date                                            Address  \
# 0     2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1     2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2     2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3     2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4     2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 5     2007-05-29   1500 West Webster Avenue, Chicago, IL 60614, USA
# 6     2007-05-29     2500 West Grand Avenue, Chicago, IL 60654, USA
# 7     2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA
# 8     2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA
# 9     2007-05-29   1100 West Chicago Avenue, Chicago, IL 60642, USA
# 10    2007-05-29    2100 North Stave Street, Chicago, IL 60647, USA
# 11    2007-05-29    2200 North Cannon Drive, Chicago, IL 60614, USA
# 12    2007-05-29    2200 North Cannon Drive, Chicago, IL 60614, USA
# ...

# %%
df['Block'].unique()
# Out:
# array([22, 35, 12, 10, 37, 38, 24, 41, 72, 42, 70, 50, 11, 13, 15, 14, 61,
#        52, 40, 91, 45, 89, 67, 82, 36, 33, 46, 51, 17, 39, 65, 58, 90, 25,
#        62, 71])

# %%
weather = pd.read_csv('./assets/input/weather.csv')
weather_stn1 = weather[weather['Station']==1]
weather_stn2 = weather[weather['Station']==2]
weather_stn1 = weather_stn1.drop('Station', axis=1)
weather_stn2 = weather_stn2.drop('Station', axis=1)
weather = weather_stn1.merge(weather_stn2, on='Date')

# %%
weather
# Out:
#             Date  Tmax_x  Tmin_x Tavg_x Depart_x  DewPoint_x WetBulb_x Heat_x  \
# 0     2007-05-01      83      50     67       14          51        56      0
# 1     2007-05-02      59      42     51       -3          42        47     14
# 2     2007-05-03      66      46     56        2          40        48      9
# 3     2007-05-04      66      49     58        4          41        50      7
# 4     2007-05-05      66      53     60        5          38        49      5
# 5     2007-05-06      68      49     59        4          30        46      6
# 6     2007-05-07      83      47     65       10          41        54      0
# 7     2007-05-08      82      54     68       12          58        62      0
# 8     2007-05-09      77      61     69       13          59        63      0
# 9     2007-05-10      84      56     70       14          52        60      0
# 10    2007-05-11      70      51     61        4          42        51      4
# ...

# %%
weather = pd.read_csv('./assets/input/weather.csv')
weather.describe()
# Out:
#            Station         Tmax         Tmin     DewPoint  ResultSpeed  \
# count  2944.000000  2944.000000  2944.000000  2944.000000  2944.000000
# mean      1.500000    76.166101    57.810462    53.457880     6.960666
# std       0.500085    11.461970    10.381939    10.675181     3.587527
# min       1.000000    41.000000    29.000000    22.000000     0.100000
# 25%       1.000000    69.000000    50.000000    46.000000     4.300000
# 50%       1.500000    78.000000    59.000000    54.000000     6.400000
# 75%       2.000000    85.000000    66.000000    62.000000     9.200000
# max       2.000000   104.000000    83.000000    75.000000    24.100000
#
#          ResultDir
# count  2944.000000
# mean     17.494905
# std      10.063609
# min       1.000000
# 25%       7.000000
# 50%      19.000000
# 75%      25.000000
# max      36.000000
