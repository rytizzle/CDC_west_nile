# %%
import pandas as pd

# %%
data_spray = pd.read_csv('./assets/input/spray.csv')

# %%
data_spray.head()
# Out:
#          Date        Time   Latitude  Longitude
# 0  2011-08-29  6:56:58 PM  42.391623 -88.089163
# 1  2011-08-29  6:57:08 PM  42.391348 -88.089163
# 2  2011-08-29  6:57:18 PM  42.391022 -88.089157
# 3  2011-08-29  6:57:28 PM  42.390637 -88.089158
# 4  2011-08-29  6:57:38 PM  42.390410 -88.088858

# %%
data_spray.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14835 entries, 0 to 14834
# Data columns (total 4 columns):
# Date         14835 non-null object
# Time         14251 non-null object
# Latitude     14835 non-null float64
# Longitude    14835 non-null float64
# dtypes: float64(2), object(2)
# memory usage: 463.7+ KB

# %%
data_spray.shape
# Out:
# (14835, 4)

# %%
data_spray['Time'].isnull().sum()
# Out:
# 584

# %%
data_spray['Date']
# Out:
# 0        2011-08-29
# 1        2011-08-29
# 2        2011-08-29
# 3        2011-08-29
# 4        2011-08-29
# 5        2011-08-29
# 6        2011-08-29
# 7        2011-08-29
# 8        2011-08-29
# 9        2011-08-29
# 10       2011-08-29
# 11       2011-08-29
# 12       2011-08-29
# 13       2011-08-29
# 14       2011-08-29
# 15       2011-08-29
# 16       2011-08-29
# 17       2011-08-29
# 18       2011-08-29
# 19       2011-08-29
# 20       2011-08-29
# 21       2011-08-29
# 22       2011-08-29
# 23       2011-08-29
# 24       2011-08-29
# 25       2011-08-29
# 26       2011-08-29
# 27       2011-08-29
# 28       2011-08-29
# 29       2011-08-29
#             ...
# 14805    2013-09-05
# 14806    2013-09-05
# 14807    2013-09-05
# 14808    2013-09-05
# 14809    2013-09-05
# 14810    2013-09-05
# 14811    2013-09-05
# 14812    2013-09-05
# 14813    2013-09-05
# 14814    2013-09-05
# 14815    2013-09-05
# 14816    2013-09-05
# 14817    2013-09-05
# 14818    2013-09-05
# ...

# %%
data_spray[data_spray['Time'].isnull()]
# Out:
#             Date Time   Latitude  Longitude
# 1030  2011-09-07  NaN  41.987092 -87.794286
# 1031  2011-09-07  NaN  41.987620 -87.794382
# 1032  2011-09-07  NaN  41.988004 -87.794574
# 1033  2011-09-07  NaN  41.988292 -87.795486
# 1034  2011-09-07  NaN  41.988100 -87.796014
# 1035  2011-09-07  NaN  41.986372 -87.794862
# 1036  2011-09-07  NaN  41.986228 -87.795582
# 1037  2011-09-07  NaN  41.984836 -87.793998
# 1038  2011-09-07  NaN  41.984836 -87.794670
# 1039  2011-09-07  NaN  41.984884 -87.795198
# 1040  2011-09-07  NaN  41.982820 -87.793182
# 1041  2011-09-07  NaN  41.982772 -87.793950
# 1042  2011-09-07  NaN  41.982772 -87.795006
# 1043  2011-09-07  NaN  41.983444 -87.795246
# 1044  2011-09-07  NaN  41.984068 -87.795438
# 1045  2011-09-07  NaN  41.984596 -87.795534
# 1046  2011-09-07  NaN  41.984980 -87.795630
# 1047  2011-09-07  NaN  41.986708 -87.796110
# 1048  2011-09-07  NaN  41.987524 -87.796302
# 1049  2011-09-07  NaN  41.988820 -87.796638
# ...

# %%
data_spray.duplicated(subset=None, keep='first')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 14805    False
# 14806    False
# 14807    False
# 14808    False
# 14809    False
# 14810    False
# 14811    False
# 14812    False
# 14813    False
# 14814    False
# 14815    False
# 14816    False
# 14817    False
# 14818    False
# 14819    False
# 14820    False
# 14821    False
# 14822    False
# 14823    False
# 14824    False
# 14825    False
# 14826    False
# 14827    False
# 14828    False
# 14829    False
# 14830    False
# 14831    False
# ...

# %%
data_train = pd.read_csv('./assets/input/train.csv')
